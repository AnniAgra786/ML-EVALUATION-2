# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df=pd.read_csv("C:/Users/lenovo/Downloads/kc_house_data.csv")

# %%
df.shape
# Out:
# (21597, 21)

# %% [markdown]
# # Explore the dataset

# %% [markdown]
# ## Check the top 10 and bottom 10 of the dataset.

# %%
df.head(10)
# Out:
#            id        date           price  bedrooms bathrooms sqft_living  \
# 0  7129300520  10/13/2014   ? 2,21,900.00         3         1        1180
# 1  6414100192  12-09-2014   ? 5,38,000.00         3      2.25        2570
# 2  5631500400   2/25/2015   ? 1,80,000.00         2         1         770
# 3  2487200875  12-09-2014   ? 6,04,000.00         4         3        1960
# 4  1954400510   2/18/2015   ? 5,10,000.00         3         2        1680
# 5  7237550310  05-12-2014  ? 12,30,000.00         4       4.5        5420
# 6  1321400060   6/27/2014   ? 2,57,500.00         3      2.25        1715
# 7  2008000270   1/15/2015   ? 2,91,850.00         3       1.5        1060
# 8  2414600126   4/15/2015   ? 2,29,500.00         3         1        1780
# 9  3793500160  03-12-2015   ? 3,23,000.00         3       2.5        1890
#
#   sqft_lot  floors waterfront view  ... grade sqft_above sqft_basement  \
# 0     5650     1.0          0    0  ...     7       1180             0
# ...

# %%
df.tail(10)
# Out:
#                id        date           price  bedrooms bathrooms sqft_living  \
# 21587  7852140040   8/25/2014   ? 5,07,250.00         3       2.5        2270
# 21588  9834201367   1/26/2015   ? 4,29,000.00         3         2        1490
# 21589  3448900210  10/14/2014   ? 6,10,685.00         4       2.5        2520
# 21590  7936000429   3/26/2015  ? 10,10,000.00         4       3.5        3510
# 21591  2997800021   2/19/2015   ? 4,75,000.00         3       2.5        1310
# 21592   263000018   5/21/2014   ? 3,60,000.00         3       2.5        1530
# 21593  6600060120   2/23/2015   ? 4,00,000.00         4       2.5        2310
# 21594  1523300141   6/23/2014   ? 4,02,101.00         2      0.75        1020
# 21595   291310100   1/16/2015   ? 4,00,000.00         3       2.5        1600
# 21596  1523300157  10/15/2014   ? 3,25,000.00         2      0.75        1020
#
#       sqft_lot  floors waterfront view  ... grade sqft_above sqft_basement  \
# ...

# %% [markdown]
# # Check for null values.

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# # Check the statistical summary and info of the data.

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.157600e+04  21576.000000  21576.000000  21576.000000  2.157600e+04
# mean   5.402655e+05      3.373053      2.115812   2080.181498  1.509514e+04
# std    3.674545e+05      0.926457      0.769224    918.212956  4.141633e+04
# min    7.800000e+04      1.000000      0.500000    370.000000  5.200000e+02
# 25%    3.220000e+05      3.000000      1.750000   1429.250000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.619000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068425e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors     condition    sqft_above  sqft_basement     sqft_lot15
# count  21576.000000  21576.000000  21576.000000   21576.000000   21576.000000
# mean       1.494044      3.409714   1788.485632     291.695866   12752.189423
# ...

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price             object
# bedrooms           int64
# bathrooms         object
# sqft_living       object
# sqft_lot          object
# floors           float64
# waterfront        object
# view              object
# condition         object
# grade             object
# sqft_above        object
# sqft_basement      int64
# yr_built          object
# yr_renovated      object
# zipcode            int64
# lat               object
# long              object
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# # Handle the null and noise values.

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
for i in df.columns:
    print(df[i].unique(),'\n')
# Out:
# [7129300520 6414100192 5631500400 ... 1523300141  291310100 1523300157]
#
# ['10/13/2014' '12-09-2014' '2/25/2015' '2/18/2015' '05-12-2014'
#  '6/27/2014' '1/15/2015' '4/15/2015' '03-12-2015' '04-03-2015' '5/27/2014'
#  '5/28/2014' '10-07-2014' '1/24/2015' '7/31/2014' '5/29/2014' '12-05-2014'
#  '4/24/2015' '5/14/2014' '8/26/2014' '07-03-2014' '5/16/2014' '11/20/2014'
#  '11-03-2014' '6/26/2014' '12-01-2014' '6/24/2014' '03-02-2015'
#  '11-10-2014' '12-03-2014' '6/13/2014' '12/30/2014' '2/13/2015'
#  '6/20/2014' '7/15/2014' '08-11-2014' '07-07-2014' '10/28/2014'
#  '7/29/2014' '7/18/2014' '3/25/2015' '7/16/2014' '4/28/2015' '03-11-2015'
#  '9/16/2014' '2/17/2015' '12/31/2014' '02-05-2015' '03-03-2015'
#  '8/19/2014' '04-07-2015' '8/27/2014' '2/23/2015' '12-10-2014' '8/28/2014'
#  '10/21/2014' '12-07-2014' '06-03-2014' '09-09-2014' '10-09-2014'
#  '8/25/2014' '06-12-2014' '09-12-2014' '01-05-2015' '06-10-2014'
#  '07-10-2014' '3/16/2015' '11-05-2014' '4/20/2015' '06-09-2014'
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df=df.loc[~df['bedrooms'].isin(['-','%','&'])]

# %%
df=df.loc[~df['bathrooms'].isin([ '-','$','&'])]

# %%
df=df.loc[~df['waterfront'].isin(['-','$','&'])]

# %%
df=df.loc[~df['condition'].isin(['-','$','&','%'])]

# %%
df=df.loc[~df['grade'].isin(['-','$','&','%'])]

# %%
df=df.loc[~df['yr_built'].isin(['-','$','&','%'])]

# %%
df=df.loc[~df['yr_renovated'].isin(['-','$','&','%'])]

# %%
df=df.loc[~df['price'].isin(['-','$','&','%'])]

# %%
df=df.loc[~df['sqft_living'].isin(['-','$','&','%'])]

# %%
df=df.loc[~df['sqft_lot'].isin(['-','$','&','%'])]

# %%
df=df.loc[~df['sqft_above'].isin(['-','$','&','%'])]

# %% [markdown]
# # Check the datatype

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price             object
# bedrooms           int64
# bathrooms         object
# sqft_living       object
# sqft_lot          object
# floors           float64
# waterfront        object
# view              object
# condition         object
# grade             object
# sqft_above        object
# sqft_basement      int64
# yr_built          object
# yr_renovated      object
# zipcode            int64
# lat               object
# long              object
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# # Data cleaning.
#
# Remove special characters or strings from the numerical value.
#
# Converting the data to its respective format(type).

# %%
df['price']=df['price'].str.replace('?','')
# Out:
# 2023-01-30 23:01:13,859 [8148] WARNING  py.warnings:109: [JupyterRequire] C:\Users\lenovo\AppData\Local\Temp\ipykernel_8148\1025876986.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['price']=df['price'].str.replace('?','')

# %%
df['price']=df['price'].str.replace(',','')

# %%
# Out:
# 0         221900.00
# 1         538000.00
# 2         180000.00
# 3         604000.00
# 4         510000.00
#             ...
# 21592     360000.00
# 21593     400000.00
# 21594     402101.00
# 21595     400000.00
# 21596     325000.00
# Name: price, Length: 21582, dtype: object

# %%
df['price']=df['price'].astype(float)
# Out:
# 2023-01-30 23:03:26,459 [8148] WARNING  py.warnings:109: [JupyterRequire] C:\Users\lenovo\AppData\Local\Temp\ipykernel_8148\3617968478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price']=df['price'].astype(float)

# %%
df['bathrooms']=df['bathrooms'].astype(float)
# Out:
# 2023-01-30 23:04:31,329 [8148] WARNING  py.warnings:109: [JupyterRequire] C:\Users\lenovo\AppData\Local\Temp\ipykernel_8148\976012136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bathrooms']=df['bathrooms'].astype(float)

# %%
df['sqft_living']=df['sqft_living'].astype(float)

# %%
df['sqft_lot']=df['sqft_lot'].astype(float)

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living      float64
# sqft_lot         float64
# floors           float64
# waterfront        object
# view              object
# condition         object
# grade             object
# sqft_above        object
# sqft_basement      int64
# yr_built          object
# yr_renovated      object
# zipcode            int64
# lat               object
# long              object
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df['waterfront']=df['waterfront'].astype(float)

# %%
df['view']=df['view'].astype(float)

# %%
df['condition']=df['condition'].astype(float)

# %%
df['grade']=df['grade'].astype(float)

# %%
df['sqft_above']=df['sqft_above'].astype(float)

# %%
df.drop(columns=['lat','long','zipcode','view','id','date','sqft_living15','sqft_living15','waterfront','grade'],inplace=True)

# %%
df.shape
# Out:
# (21576, 12)

# %% [markdown]
# # Handle the Outliers.

# %%
df.shape
# Out:
# (21576, 12)

# %%
df.dtypes
# Out:
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living      float64
# sqft_lot         float64
# floors           float64
# condition         object
# sqft_above       float64
# sqft_basement      int64
# yr_built          object
# yr_renovated      object
# sqft_lot15         int64
# dtype: object

# %%
df.drop(columns='sqft_lot15',inplace=True)

# %%
df.drop(columns=['yr_built'],inplace=True)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'condition', 'sqft_above', 'sqft_basement', 'yr_renovated'],
#       dtype='object')

# %% [markdown]
# # Handle the Outliers.

# %%
col=['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
       'sqft_above', 'sqft_basement']

# %%
for e in col:
     plt.figure()
     sns.boxplot(y=e, data=df)

# %%
for e in col:
  percentile25=df[e].quantile(0.25)
  percentile75=df[e].quantile(0.75)
  iqr=percentile75-percentile25
  upper_limit=percentile75+(1.5*iqr)
  lower_limit=percentile25-(1.5*iqr)
  df=df[df[e]<=upper_limit]
  df=df[df[e]>=lower_limit]
  plt.figure()
  sns.boxplot(y=e, data=df)

# %% [markdown]
# # Use any scaling type for feature scaling.

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'condition', 'sqft_above', 'sqft_basement', 'yr_renovated'],
#       dtype='object')

# %%
df.drop(columns='yr_renovated',inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
le=LabelEncoder()

# %%
df['condition']=le.fit_transform(df['condition'])

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'condition', 'sqft_above', 'sqft_basement'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'condition', 'sqft_above', 'sqft_basement'],
#       dtype='object')

# %% [markdown]
# # Apply the scaling on numerical columns

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc_x=StandardScaler()

# %%
x_train=sc_x.fit_transform(x_train)

# %%
x_test=sc_x.transform(x_test)

# %%
x=df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'condition', 'sqft_above', 'sqft_basement']]

# %%
y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Splitting the data.

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=45)

# %% [markdown]
# # Split the data into train and test.
#
# Create a Model.

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %% [markdown]
# # Train the model.

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Get the prediction of the model for both training and testing data

# %%
y_pred=reg.predict(x_test)

# %%
y_pred1=reg.predict(x_train)

# %% [markdown]
# # Get the accuracy of the model with the help of different metrics.

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 20969407606.764248

# %%
mean_squared_error(y_train, y_pred1)
# Out:
# 21026105292.988632

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 144808.17520694144

# %%
np.sqrt(mean_squared_error(y_train, y_pred1))
# Out:
# 145003.8113050434

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.30132074654723096

# %%
r2_score(y_train, y_pred1)
# Out:
# 0.31126248203838724
